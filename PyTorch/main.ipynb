# %%
import os
import torch
import torchaudio
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
import wave

def check_wav_specs(file_path):
    with wave.open(file_path, 'rb') as wav_file:
        sample_rate = wav_file.getframerate()
        num_channels = wav_file.getnchannels()
        num_frames = wav_file.getnframes()

        print(f"Sample Rate: {sample_rate} Hz")
        print(f"KanÃ¤le: {num_channels}")
        print(f"Frames: {num_frames}")
        print(f"Dauer: {num_frames / sample_rate:.2f} Sekunden")

check_wav_specs("../dataset/yes/00f0204f_nohash_0.wav")
# Out:
# Sample Rate: 16000 Hz
# KanÃ¤le: 1
# Frames: 16000
# Dauer: 1.00 Sekunden

# %%
# Check GPU
import torch

def check_gpu_status():
    cuda_available = torch.cuda.is_available()
    print(f"CUDA Available: {cuda_available}")

    if cuda_available:
        num_gpus = torch.cuda.device_count()
        print(f"Number of GPUs detected: {num_gpus}\n")
        for i in range(num_gpus):
            print(f"--- GPU {i} ---")
            print(f"Name: {torch.cuda.get_device_name(i)}")
            print(f"Compute Capability: {torch.cuda.get_device_capability(i)}")
            total_memory = torch.cuda.get_device_properties(i).total_memory / (1024**3)
            print(f"Total Memory: {total_memory:.2f} GB")
    else:
        print("PyTorch cannot detect a compatible GPU. It will default to CPU.")

check_gpu_status()
# Out:
# CUDA Available: True
# Number of GPUs detected: 1
#
# --- GPU 0 ---
# Name: NVIDIA GeForce RTX 5070 Laptop GPU
# Compute Capability: (12, 0)
# Total Memory: 7.96 GB

# %%
# 1. Configuration
DATA_DIR = "../dataset/"
CLASSES = ["yes", "no", "up", "down"]
TARGET_SAMPLE_RATE = 16000
NUM_SAMPLES = 16000 # 1 second of audio
BATCH_SIZE = 32
EPOCHS = 40
LEARNING_RATE = 0.001
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 2. Data Preparation
def get_files_and_labels():
    file_paths = []
    labels = []
    class_to_idx = {cls_name: i for i, cls_name in enumerate(CLASSES)}

    for cls_name in CLASSES:
        cls_dir = os.path.join(DATA_DIR, cls_name)
        if not os.path.exists(cls_dir):
            continue
        for file in os.listdir(cls_dir):
            if file.endswith(".wav"):
                file_paths.append(os.path.join(cls_dir, file))
                labels.append(class_to_idx[cls_name])

    return file_paths, labels


file_paths, labels = get_files_and_labels()
train_paths, test_paths, train_labels, test_labels = train_test_split(
    file_paths, labels, test_size=0.2, stratify=labels, random_state=42
)

# %%
import soundfile as sf
import time

# --- DATASET FIX (Speedup) ---
class KeywordDataset(Dataset):
    def __init__(self, paths, labels):
        self.paths = paths
        self.labels = labels

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        clean_path = os.path.normpath(self.paths[idx])
        # Use soundfile directly to bypass ALL torchaudio/torchcodec backend errors
        waveform_np, sr = sf.read(clean_path, dtype="float32")
        waveform = torch.from_numpy(waveform_np)

        # Format shapes correctly
        if waveform.ndim == 1:
            waveform = waveform.unsqueeze(0)
        else:
            waveform = waveform.t()

        # Convert to mono if stereo
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)

        # Pad or cut to exactly 1 second (16000 samples)
        if waveform.shape[1] > NUM_SAMPLES:
            waveform = waveform[:, :NUM_SAMPLES]
        elif waveform.shape[1] < NUM_SAMPLES:
            waveform = F.pad(waveform, (0, NUM_SAMPLES - waveform.shape[1]))

        # We return the RAW waveform. We will turn it into a Spectrogram on the GPU!
        return waveform, torch.tensor(self.labels[idx], dtype=torch.long)

# --- MODEL ARCHITECTURE (Added 3rd Layer for 95% Accuracy) ---
class KeywordCNN(nn.Module):
    def __init__(self, num_classes):
        super(KeywordCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1) # <-- NEW LAYER

        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(0.3)
        self.adaptive_pool = nn.AdaptiveAvgPool2d((4, 4))

        self.fc1 = nn.Linear(64 * 4 * 4, 128) # Updated input size for new layer
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x))) # Apply the new layer
        x = self.adaptive_pool(x)
        x = torch.flatten(x, 1)
        x = self.dropout(F.relu(self.fc1(x)))
        logits = self.fc2(x)
        return logits

    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits, dim=1)


# --- MAIN TRAINING LOOP WRAPPER (Prevents Windows Freeze!) ---
def train_model():
    # Define DataLoaders inside the function with num_workers=0
    train_loader = DataLoader(KeywordDataset(train_paths, train_labels), batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
    test_loader = DataLoader(KeywordDataset(test_paths, test_labels), batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)

    model = KeywordCNN(num_classes=len(CLASSES)).to(DEVICE)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    # Setup GPU Spectrogram
    mel_transform = torchaudio.transforms.MelSpectrogram(
        sample_rate=TARGET_SAMPLE_RATE, n_mels=64
    ).to(DEVICE)

    print(f"Training on {DEVICE}...")

    for epoch in range(EPOCHS):
        start_time = time.time()
        model.train()
        total_loss = 0
        correct = 0
        total = 0

        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)

            with torch.no_grad():
                inputs = mel_transform(inputs)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

            if (batch_idx + 1) % 50 == 0:
                print(f"Epoch [{epoch+1}/{EPOCHS}] | Batch [{batch_idx+1}/{len(train_loader)}] | Loss: {loss.item():.4f}")

        train_acc = 100. * correct / total

        # Validation
        model.eval()
        test_correct = 0
        test_total = 0
        with torch.no_grad():
            for inputs, targets in test_loader:
                inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
                inputs = mel_transform(inputs)
                outputs = model(inputs)
                _, predicted = outputs.max(1)
                test_total += targets.size(0)
                test_correct += predicted.eq(targets).sum().item()

        test_acc = 100. * test_correct / test_total
        dur = time.time() - start_time

        print(f"=== Epoch {epoch+1}/{EPOCHS} [{dur:.2f}s] Summary | Train Loss: {total_loss/len(train_loader):.4f} | Train Acc: {train_acc:.2f}% | Test Acc: {test_acc:.2f}% ===\n")

    print("Training complete.")

# 5. Execute Training Loop!
if __name__ == '__main__':
    train_model()
# Out:
# Training on cuda...
# Epoch [1/40] | Batch [50/238] | Loss: 1.1798
# Epoch [1/40] | Batch [100/238] | Loss: 1.1002
# Epoch [1/40] | Batch [150/238] | Loss: 0.6976
# Epoch [1/40] | Batch [200/238] | Loss: 0.8624
# === Epoch 1/40 [3.70s] Summary | Train Loss: 1.1290 | Train Acc: 58.26% | Test Acc: 74.34% ===
#
# Epoch [2/40] | Batch [50/238] | Loss: 0.6873
# Epoch [2/40] | Batch [100/238] | Loss: 0.5892
# Epoch [2/40] | Batch [150/238] | Loss: 0.6815
# Epoch [2/40] | Batch [200/238] | Loss: 0.7576
# === Epoch 2/40 [3.39s] Summary | Train Loss: 0.6574 | Train Acc: 77.44% | Test Acc: 85.83% ===
#
# Epoch [3/40] | Batch [50/238] | Loss: 0.2324
# Epoch [3/40] | Batch [100/238] | Loss: 0.4341
# Epoch [3/40] | Batch [150/238] | Loss: 0.4148
# Epoch [3/40] | Batch [200/238] | Loss: 0.5102
# === Epoch 3/40 [3.27s] Summary | Train Loss: 0.5237 | Train Acc: 81.93% | Test Acc: 86.88% ===
#
# Epoch [4/40] | Batch [50/238] | Loss: 0.3506
# Epoch [4/40] | Batch [100/238] | Loss: 0.3795
# Epoch [4/40] | Batch [150/238] | Loss: 0.4912
# Epoch [4/40] | Batch [200/238] | Loss: 0.4442
# === Epoch 4/40 [3.35s] Summary | Train Loss: 0.4180 | Train Acc: 85.99% | Test Acc: 84.40% ===
#
# Epoch [5/40] | Batch [50/238] | Loss: 0.4337
# Epoch [5/40] | Batch [100/238] | Loss: 0.3852
# Epoch [5/40] | Batch [150/238] | Loss: 0.4559
# Epoch [5/40] | Batch [200/238] | Loss: 0.1538
# === Epoch 5/40 [3.28s] Summary | Train Loss: 0.3280 | Train Acc: 88.60% | Test Acc: 90.25% ===
#
# Epoch [6/40] | Batch [50/238] | Loss: 0.1941
# Epoch [6/40] | Batch [100/238] | Loss: 0.2845
# Epoch [6/40] | Batch [150/238] | Loss: 0.2253
# Epoch [6/40] | Batch [200/238] | Loss: 0.3500
# === Epoch 6/40 [3.20s] Summary | Train Loss: 0.2979 | Train Acc: 90.12% | Test Acc: 91.36% ===
#
# Epoch [7/40] | Batch [50/238] | Loss: 0.0576
# Epoch [7/40] | Batch [100/238] | Loss: 0.2541
# Epoch [7/40] | Batch [150/238] | Loss: 0.1833
# Epoch [7/40] | Batch [200/238] | Loss: 0.2407
# === Epoch 7/40 [3.36s] Summary | Train Loss: 0.2507 | Train Acc: 91.33% | Test Acc: 91.36% ===
#
# Epoch [8/40] | Batch [50/238] | Loss: 0.0886
# Epoch [8/40] | Batch [100/238] | Loss: 0.1062
# Epoch [8/40] | Batch [150/238] | Loss: 0.0958
# Epoch [8/40] | Batch [200/238] | Loss: 0.1930
# === Epoch 8/40 [3.37s] Summary | Train Loss: 0.2387 | Train Acc: 92.00% | Test Acc: 88.94% ===
#
# Epoch [9/40] | Batch [50/238] | Loss: 0.3587
# Epoch [9/40] | Batch [100/238] | Loss: 0.2279
# Epoch [9/40] | Batch [150/238] | Loss: 0.3275
# Epoch [9/40] | Batch [200/238] | Loss: 0.0619
# === Epoch 9/40 [3.58s] Summary | Train Loss: 0.2216 | Train Acc: 92.51% | Test Acc: 93.36% ===
#
# Epoch [10/40] | Batch [50/238] | Loss: 0.0562
# Epoch [10/40] | Batch [100/238] | Loss: 0.1427
# Epoch [10/40] | Batch [150/238] | Loss: 0.0422
# Epoch [10/40] | Batch [200/238] | Loss: 0.0594
# === Epoch 10/40 [3.35s] Summary | Train Loss: 0.1712 | Train Acc: 93.94% | Test Acc: 90.73% ===
#
# Epoch [11/40] | Batch [50/238] | Loss: 0.1178
# Epoch [11/40] | Batch [100/238] | Loss: 0.3323
# Epoch [11/40] | Batch [150/238] | Loss: 0.2136
# Epoch [11/40] | Batch [200/238] | Loss: 0.1113
# === Epoch 11/40 [3.49s] Summary | Train Loss: 0.2141 | Train Acc: 93.02% | Test Acc: 92.57% ===
#
# Epoch [12/40] | Batch [50/238] | Loss: 0.4331
# Epoch [12/40] | Batch [100/238] | Loss: 0.0462
# Epoch [12/40] | Batch [150/238] | Loss: 0.1704
# Epoch [12/40] | Batch [200/238] | Loss: 0.1121
# === Epoch 12/40 [3.42s] Summary | Train Loss: 0.1375 | Train Acc: 94.95% | Test Acc: 93.10% ===
#
# Epoch [13/40] | Batch [50/238] | Loss: 0.1131
# Epoch [13/40] | Batch [100/238] | Loss: 0.2338
# Epoch [13/40] | Batch [150/238] | Loss: 0.1993
# Epoch [13/40] | Batch [200/238] | Loss: 0.0392
# === Epoch 13/40 [3.28s] Summary | Train Loss: 0.1756 | Train Acc: 94.41% | Test Acc: 92.15% ===
#
# Epoch [14/40] | Batch [50/238] | Loss: 0.0475
# Epoch [14/40] | Batch [100/238] | Loss: 0.4375
# Epoch [14/40] | Batch [150/238] | Loss: 0.1011
# Epoch [14/40] | Batch [200/238] | Loss: 0.0966
# === Epoch 14/40 [3.46s] Summary | Train Loss: 0.1730 | Train Acc: 94.33% | Test Acc: 93.84% ===
#
# Epoch [15/40] | Batch [50/238] | Loss: 0.1199
# Epoch [15/40] | Batch [100/238] | Loss: 0.0431
# Epoch [15/40] | Batch [150/238] | Loss: 0.0546
# Epoch [15/40] | Batch [200/238] | Loss: 0.1406
# === Epoch 15/40 [3.42s] Summary | Train Loss: 0.1289 | Train Acc: 95.32% | Test Acc: 94.20% ===
#
# Epoch [16/40] | Batch [50/238] | Loss: 0.0808
# Epoch [16/40] | Batch [100/238] | Loss: 0.0079
# Epoch [16/40] | Batch [150/238] | Loss: 0.0716
# Epoch [16/40] | Batch [200/238] | Loss: 0.0576
# === Epoch 16/40 [3.31s] Summary | Train Loss: 0.1141 | Train Acc: 95.98% | Test Acc: 93.36% ===
#
# Epoch [17/40] | Batch [50/238] | Loss: 0.0450
# Epoch [17/40] | Batch [100/238] | Loss: 0.0563
# Epoch [17/40] | Batch [150/238] | Loss: 0.0342
# Epoch [17/40] | Batch [200/238] | Loss: 0.0354
# === Epoch 17/40 [3.42s] Summary | Train Loss: 0.1023 | Train Acc: 96.60% | Test Acc: 93.73% ===
#
# Epoch [18/40] | Batch [50/238] | Loss: 0.0687
# Epoch [18/40] | Batch [100/238] | Loss: 0.3311
# Epoch [18/40] | Batch [150/238] | Loss: 0.3606
# Epoch [18/40] | Batch [200/238] | Loss: 0.3265
# === Epoch 18/40 [3.42s] Summary | Train Loss: 0.2998 | Train Acc: 92.01% | Test Acc: 93.52% ===
#
# Epoch [19/40] | Batch [50/238] | Loss: 0.0468
# Epoch [19/40] | Batch [100/238] | Loss: 0.6177
# Epoch [19/40] | Batch [150/238] | Loss: 0.0984
# Epoch [19/40] | Batch [200/238] | Loss: 0.1362
# === Epoch 19/40 [3.39s] Summary | Train Loss: 0.1796 | Train Acc: 94.69% | Test Acc: 94.26% ===
#
# Epoch [20/40] | Batch [50/238] | Loss: 0.0213
# Epoch [20/40] | Batch [100/238] | Loss: 0.0674
# Epoch [20/40] | Batch [150/238] | Loss: 0.0372
# Epoch [20/40] | Batch [200/238] | Loss: 0.1687
# === Epoch 20/40 [3.37s] Summary | Train Loss: 0.1637 | Train Acc: 95.16% | Test Acc: 94.20% ===
#
# Epoch [21/40] | Batch [50/238] | Loss: 0.1416
# Epoch [21/40] | Batch [100/238] | Loss: 0.1008
# Epoch [21/40] | Batch [150/238] | Loss: 0.0310
# Epoch [21/40] | Batch [200/238] | Loss: 0.0361
# === Epoch 21/40 [3.40s] Summary | Train Loss: 0.1024 | Train Acc: 96.36% | Test Acc: 94.89% ===
#
# Epoch [22/40] | Batch [50/238] | Loss: 0.0418
# Epoch [22/40] | Batch [100/238] | Loss: 0.1051
# Epoch [22/40] | Batch [150/238] | Loss: 0.0335
# Epoch [22/40] | Batch [200/238] | Loss: 0.0323
# === Epoch 22/40 [3.36s] Summary | Train Loss: 0.0821 | Train Acc: 96.94% | Test Acc: 95.42% ===
#
# Epoch [23/40] | Batch [50/238] | Loss: 0.0555
# Epoch [23/40] | Batch [100/238] | Loss: 0.0261
# Epoch [23/40] | Batch [150/238] | Loss: 0.0577
# Epoch [23/40] | Batch [200/238] | Loss: 0.0121
# === Epoch 23/40 [3.41s] Summary | Train Loss: 0.0833 | Train Acc: 96.97% | Test Acc: 95.42% ===
#
# Epoch [24/40] | Batch [50/238] | Loss: 0.0044
# Epoch [24/40] | Batch [100/238] | Loss: 0.0454
# Epoch [24/40] | Batch [150/238] | Loss: 0.0837
# Epoch [24/40] | Batch [200/238] | Loss: 0.0802
# === Epoch 24/40 [3.44s] Summary | Train Loss: 0.0775 | Train Acc: 97.22% | Test Acc: 92.68% ===
#
# Epoch [25/40] | Batch [50/238] | Loss: 0.0562
# Epoch [25/40] | Batch [100/238] | Loss: 0.1800
# Epoch [25/40] | Batch [150/238] | Loss: 0.0798
# Epoch [25/40] | Batch [200/238] | Loss: 0.1392
# === Epoch 25/40 [3.29s] Summary | Train Loss: 0.0927 | Train Acc: 96.63% | Test Acc: 94.84% ===
#
# Epoch [26/40] | Batch [50/238] | Loss: 0.0411
# Epoch [26/40] | Batch [100/238] | Loss: 0.0177
# Epoch [26/40] | Batch [150/238] | Loss: 0.0297
# Epoch [26/40] | Batch [200/238] | Loss: 0.3902
# === Epoch 26/40 [3.60s] Summary | Train Loss: 0.0861 | Train Acc: 96.97% | Test Acc: 95.15% ===
#
# Epoch [27/40] | Batch [50/238] | Loss: 0.0057
# Epoch [27/40] | Batch [100/238] | Loss: 0.0445
# Epoch [27/40] | Batch [150/238] | Loss: 0.0506
# Epoch [27/40] | Batch [200/238] | Loss: 0.0516
# === Epoch 27/40 [3.39s] Summary | Train Loss: 0.0664 | Train Acc: 97.42% | Test Acc: 95.52% ===
#
# Epoch [28/40] | Batch [50/238] | Loss: 0.0319
# Epoch [28/40] | Batch [100/238] | Loss: 0.0574
# Epoch [28/40] | Batch [150/238] | Loss: 0.0477
# Epoch [28/40] | Batch [200/238] | Loss: 0.0476
# === Epoch 28/40 [3.42s] Summary | Train Loss: 0.0778 | Train Acc: 97.27% | Test Acc: 94.57% ===
#
# Epoch [29/40] | Batch [50/238] | Loss: 0.1637
# Epoch [29/40] | Batch [100/238] | Loss: 0.1536
# Epoch [29/40] | Batch [150/238] | Loss: 0.0259
# Epoch [29/40] | Batch [200/238] | Loss: 0.2226
# === Epoch 29/40 [3.52s] Summary | Train Loss: 0.1039 | Train Acc: 96.82% | Test Acc: 93.62% ===
#
# Epoch [30/40] | Batch [50/238] | Loss: 0.0670
# Epoch [30/40] | Batch [100/238] | Loss: 0.0918
# Epoch [30/40] | Batch [150/238] | Loss: 0.0339
# Epoch [30/40] | Batch [200/238] | Loss: 0.0126
# === Epoch 30/40 [3.36s] Summary | Train Loss: 0.1280 | Train Acc: 96.02% | Test Acc: 95.42% ===
#
# Epoch [31/40] | Batch [50/238] | Loss: 0.0445
# Epoch [31/40] | Batch [100/238] | Loss: 0.1464
# Epoch [31/40] | Batch [150/238] | Loss: 0.0558
# Epoch [31/40] | Batch [200/238] | Loss: 0.0716
# === Epoch 31/40 [3.48s] Summary | Train Loss: 0.0863 | Train Acc: 97.05% | Test Acc: 94.05% ===
#
# Epoch [32/40] | Batch [50/238] | Loss: 0.0342
# Epoch [32/40] | Batch [100/238] | Loss: 0.0790
# Epoch [32/40] | Batch [150/238] | Loss: 0.0032
# Epoch [32/40] | Batch [200/238] | Loss: 0.0221
# === Epoch 32/40 [3.41s] Summary | Train Loss: 0.0620 | Train Acc: 97.80% | Test Acc: 95.15% ===
#
# Epoch [33/40] | Batch [50/238] | Loss: 0.0639
# Epoch [33/40] | Batch [100/238] | Loss: 0.0123
# Epoch [33/40] | Batch [150/238] | Loss: 0.1644
# Epoch [33/40] | Batch [200/238] | Loss: 0.1625
# === Epoch 33/40 [3.34s] Summary | Train Loss: 0.0678 | Train Acc: 97.76% | Test Acc: 94.42% ===
#
# Epoch [34/40] | Batch [50/238] | Loss: 0.0586
# Epoch [34/40] | Batch [100/238] | Loss: 0.2413
# Epoch [34/40] | Batch [150/238] | Loss: 0.0372
# Epoch [34/40] | Batch [200/238] | Loss: 0.1394
# === Epoch 34/40 [3.27s] Summary | Train Loss: 0.0674 | Train Acc: 97.52% | Test Acc: 95.31% ===
#
# Epoch [35/40] | Batch [50/238] | Loss: 0.0340
# Epoch [35/40] | Batch [100/238] | Loss: 0.0739
# Epoch [35/40] | Batch [150/238] | Loss: 0.0198
# Epoch [35/40] | Batch [200/238] | Loss: 0.1458
# === Epoch 35/40 [3.41s] Summary | Train Loss: 0.0513 | Train Acc: 98.06% | Test Acc: 94.31% ===
#
# Epoch [36/40] | Batch [50/238] | Loss: 0.1826
# Epoch [36/40] | Batch [100/238] | Loss: 0.0061
# Epoch [36/40] | Batch [150/238] | Loss: 0.0184
# Epoch [36/40] | Batch [200/238] | Loss: 0.0056
# === Epoch 36/40 [3.35s] Summary | Train Loss: 0.0748 | Train Acc: 97.73% | Test Acc: 94.15% ===
#
# Epoch [37/40] | Batch [50/238] | Loss: 0.0156
# Epoch [37/40] | Batch [100/238] | Loss: 0.1049
# Epoch [37/40] | Batch [150/238] | Loss: 0.0723
# Epoch [37/40] | Batch [200/238] | Loss: 0.0029
# === Epoch 37/40 [3.34s] Summary | Train Loss: 0.0658 | Train Acc: 97.54% | Test Acc: 95.31% ===
#
# Epoch [38/40] | Batch [50/238] | Loss: 0.0305
# Epoch [38/40] | Batch [100/238] | Loss: 0.0351
# Epoch [38/40] | Batch [150/238] | Loss: 0.0405
# Epoch [38/40] | Batch [200/238] | Loss: 0.0283
# === Epoch 38/40 [3.41s] Summary | Train Loss: 0.0681 | Train Acc: 97.87% | Test Acc: 95.26% ===
#
# Epoch [39/40] | Batch [50/238] | Loss: 0.0146
# Epoch [39/40] | Batch [100/238] | Loss: 0.0043
# Epoch [39/40] | Batch [150/238] | Loss: 0.1410
# Epoch [39/40] | Batch [200/238] | Loss: 0.0184
# === Epoch 39/40 [3.35s] Summary | Train Loss: 0.0549 | Train Acc: 98.14% | Test Acc: 94.57% ===
#
# Epoch [40/40] | Batch [50/238] | Loss: 0.0007
# Epoch [40/40] | Batch [100/238] | Loss: 0.0073
# Epoch [40/40] | Batch [150/238] | Loss: 0.0419
# Epoch [40/40] | Batch [200/238] | Loss: 0.0017
# === Epoch 40/40 [3.43s] Summary | Train Loss: 0.0872 | Train Acc: 97.27% | Test Acc: 94.10% ===
#
# Training complete.
